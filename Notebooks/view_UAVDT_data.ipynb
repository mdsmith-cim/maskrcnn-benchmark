# %%
UAVDT_DIR = '/APL/Datasets/UAVBenchmark-COCO-format/'

# %%
import pandas as pd
import os
import glob
import json
from pycocotools import cocoeval
# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (12.0, 12.0)

# %% [markdown]
# ## View VisDrone data using COCO API

# %%
coco_format_train = os.path.join(UAVDT_DIR, 'train.json')

with open(coco_format_train) as f:
    annotation = json.load(f)

annotation
# Out:
# {'info': {'description': 'UAVDT Benchmark',
#   'url': 'https://sites.google.com/site/daviddo0323/projects/uavdt',
#   'version': '1.0',
#   'year': 2019,
#   'contributor': 'Dawei Du et. al., this format: Michael Smith @McGill University',
#   'date_created': '2019/07/07'},
#  'images': [{'file_name': 'img0401000160.jpg',
#    'height': 540,
#    'width': 1024,
#    'id': 401000160},
#   {'file_name': 'img0401000589.jpg',
#    'height': 540,
#    'width': 1024,
#    'id': 401000589},
#   {'file_name': 'img0401000255.jpg',
#    'height': 540,
#    'width': 1024,
#    'id': 401000255},
#   {'file_name': 'img0401000373.jpg',
#    'height': 540,
#    'width': 1024,
#    'id': 401000373},
#   {'file_name': 'img0401000487.jpg',
#    'height': 540,
#    'width': 1024,
#    'id': 401000487},
#   {'file_name': 'img0401000240.jpg',
#    'height': 540,
#    'width': 1024,
#    'id': 401000240},
#   {'file_name': 'img0401000511.jpg',
#    'height': 540,
#    'width': 1024,
# ...

# %%
SET = 'train'
#SET = 'test'
annFile = os.path.join(UAVDT_DIR, SET + '.json')
IMG_DIR = os.path.join(UAVDT_DIR, SET)

# %%
annFile
# Out:
# '/APL/Datasets/UAVBenchmark-COCO-format/train.json'

# %%
coco=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=5.29s)
# creating index...
# index created!

# %%
imgIds = coco.getImgIds()
#img = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]
img = coco.loadImgs(imgIds[0])[0]

# %%
img
# Out:
# {'file_name': 'img1001001484.jpg',
#  'height': 540,
#  'width': 1024,
#  'id': 1001001484}

# %%
# load and display image
# I = io.imread('%s/images/%s/%s'%(dataDir,dataType,img['file_name']))
# use url to load image
I = io.imread(os.path.join(IMG_DIR, img['file_name']))
plt.axis('off')
plt.imshow(I)
plt.show()

# %%
# load and display instance annotations
plt.imshow(I); plt.axis('off')
annIds = coco.getAnnIds(imgIds=img['id'])
anns = coco.loadAnns(annIds)
coco.showAnns(anns)

# %%
len(imgIds)
# Out:
# 24143
